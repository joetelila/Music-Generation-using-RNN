# %% [markdown]
# # Hidden markov model generalized to 2 parenting relationship (also ngram model, n=3)

# %%
# P(X_i|X_i-1,X_i-2)

# %%
import nltk
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle 
import json
import os
from pathlib import Path
from IPython.display import Image, Audio
from music21 import note , chord , stream , instrument , converter   
import mido

# %%
# create a dict with the ngram model, it receives a list with the samples as string
ngram_dict = {}

def create_trigram_dict(corpus):
    n = 3
    ngrams = nltk.ngrams(corpus, n)
    
    for grams in ngrams:
        dict_key = grams[:-1][0] + " " + grams[:-1][1]
        if dict_key in ngram_dict:
            ngram_dict[dict_key].append(grams[-1])
        else:
            ngram_dict[dict_key] = []
            ngram_dict[dict_key].append(grams[-1])

# %%
def generate_trigram(seed, samples, ngram_dict):
    output = seed  
    for i in range(samples):
        # When it reaches the last prefix, there is no suffix, so end
        try:
            new_sample = random.choice(ngram_dict[seed])
        except:
            return output
        output += " " + new_sample
        seed = seed.split(" ")[1] + " " + new_sample

    return output

# %%
songs = []
for filename in os.listdir("dataset/midi_songs"):
    if filename.endswith(".mid"): 
        #print(filename)
        s = 'dataset/midi_songs/'+filename
        #song = mido.MidiFile(s)
        conv = converter.parse(s)
        songs.append(conv)
        continue
    else:
        continue

# %%
notes = []
for s in songs:
    notes_to_parse = s.flat.notes
    notes.append(notes_to_parse)

# %%
notes[:5]
# Out:
# [<music21.stream.iterator.StreamIterator for Score:0x2d0006910 @:0>,
#  <music21.stream.iterator.StreamIterator for Score:0x2986c51f0 @:0>,
#  <music21.stream.iterator.StreamIterator for Score:0x2cffb0880 @:0>,
#  <music21.stream.iterator.StreamIterator for Score:0x2a7c81670 @:0>,
#  <music21.stream.iterator.StreamIterator for Score:0x2a4159d60 @:0>]

# %%
#                                      song1  song2
#generate list of list of notes --> [[A,F,C],[D,G,B]]
listoflists = []
for n in notes:
    notes_demo = []
    for element in n:
        # if the element is a Note , then store it's Pitch
        if isinstance(element , note.Note):
            notes_demo.append(str(element.pitch))
        
        elif isinstance(element , chord.Chord):
            notes_demo.append('+'.join(str(n) for n in element.normalOrder))
            
    listoflists.append(notes_demo)

# %%
# converting into a single string each song in listoflists
final = []
for song in listoflists:
    l = song
    melody = ''
    for i in l:
        melody = melody + ' ' + i
    final.append(melody)
    melody = ''

# %%
dictionaries = []
for progression in final:
    ngram_dict = {}
    create_trigram_dict(progression.split(" "))
    dictionaries.append(ngram_dict)

# %%
dictionaries[6]
# Out:
# {' A4': ['D4'],
#  'A4 D4': ['B-4', 'F4', 'D5'],
#  'D4 B-4': ['F4', 'B-3'],
#  'B-4 F4': ['F5'],
#  'F4 F5': ['C4', 'E5', 'E5'],
#  'F5 C4': ['G4', 'E4'],
#  'C4 G4': ['E4', 'E4', 'C5', 'C5', 'C5', 'C5', 'C5', 'C5'],
#  'G4 E4': ['A4', 'A4'],
#  'E4 A4': ['B-3', 'B-3', 'C4', 'D5', 'D5'],
#  'A4 B-3': ['E5', 'D4', 'B-4'],
#  'B-3 E5': ['D4', 'D4'],
#  'E5 D4': ['F4', 'G4', 'G4', 'B-3', 'A3'],
#  'D4 F4': ['A3',
#   'A4',
#   'D4',
#   'A4',
#   'E5',
#   'E5',
#   'E5',
#   'A4',
#   'C5',
#   'D4',
#   'D4',
#   'E5',
#   'E5',
#   'E5',
#   'A4',
#   'C5',
#   'D4',
#   'D4'],
#  'F4 A3': ['C5'],
#  'A3 C5': ['C4'],
#  'C5 C4': ['D5'],
#  'C4 D5': ['G3', 'D3', 'B-3', 'B-3'],
#  'D5 G3': ['E4', 'C5', 'E5'],
#  'G3 E4': ['B-3'],
#  'E4 B-3': ['F4'],
#  'B-3 F4': ['D4'],
#  'F4 D4': ['C5',
#   'A3',
#   'B-3',
#   'B-3',
#   'G5',
#   'G5',
#   'C4',
#   'B-3',
#   'B-3',
#   'G5',
#   'G5',
#   'F5'],
#  'D4 C5': ['0+4'],
#  'C5 0+4': ['A2'],
#  '0+4 A2': ['A4'],
#  'A2 A4': ['D4'],
#  'F4 A4': ['F4', 'D4', 'B-5', 'G5', 'B-5', 'E5', 'B-5', 'G5', 'B-5', 'E5'],
#  'A4 F4': ['E5'],
#  'F4 E5': ['C4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4'],
#  'E5 C4': ['E4',
#   'E4',
#   'E4',
#   'G4',
#   'E4',
#   'E4',
#   'E4',
#   'E4',
#   'F5',
#   'E4',
#   'G4',
#   'E4',
#   'E4',
#   'E4',
#   'A3',
#   'A5'],
#  'C4 E4': ['G4',
#   'G4',
#   'F5',
#   'F5',
#   'C5',
#   'G4',
#   '10+2+5',
#   'C4',
#   'C4',
#   'C4',
#   'G5',
#   'D5',
#   'F5',
#   'F5',
#   'F5',
#   'C5',
#   'G4',
#   '10+2+5',
#   'C4',
#   'C4',
#   'C4',
#   'G4'],
#  'E4 G4': ['E5', 'G5', 'D5', 'D5', 'A5'],
#  'G4 E5': ['E4', 'F5'],
#  'E5 E4': ['A4', 'C4', 'C4', 'C4'],
#  'B-3 D4': ['F4',
#   'F4',
#   'B-3',
#   'G5',
#   'F4',
#   'F4',
#   'A5',
#   'F5',
#   'F4',
#   'B-4',
#   'A5',
#   'G5',
#   'F4',
#   'F4',
#   'A5',
#   'F5',
#   'F4',
#   'B-3'],
#  'D4 A3': ['C4', 'D3'],
#  'A3 C4': ['G4',
#   'B-4',
#   'E5',
#   'E4',
#   'E4',
#   'E4',
#   'C6',
#   'E5',
#   'E4',
#   'E4',
#   'E4',
#   'E4',
#   'C6',
#   'E5',
#   'E4'],
#  'A4 C4': ['D4'],
#  'C4 D4': ['7+10'],
#  'D4 7+10': ['A4'],
#  '7+10 A4': ['A4'],
#  'A4 A4': ['G4'],
#  'A4 G4': ['10+0', 'C3', 'C3', 'C3', 'C3'],
#  'G4 10+0': ['E4'],
#  '10+0 E4': ['C4'],
#  'E4 C4': ['A4',
#   'D5',
#   'A3',
#   'A3',
#   'A5',
#   'D5',
#   'A3',
#   '9+0+4',
#   'A3',
#   'A3',
#   'A5',
#   'D5',
#   'A3',
#   '9+0+4'],
#  'C4 A4': ['F3'],
#  'A4 F3': ['A3', 'B-4', 'G4', 'B-4', 'B-4', 'G4', 'B-4'],
#  'F3 A3': ['C4'],
#  'C4 B-4': ['A3'],
#  'B-4 A3': ['A4'],
#  'A3 A4': ['9+2', 'G5', 'E5'],
#  'A4 9+2': ['9+1'],
#  '9+2 9+1': ['D5'],
#  '9+1 D5': ['B-3'],
#  'D5 B-3': ['D4', 'D4', 'F5', 'D4', 'F5'],
#  'D4 D5': ['E5', 'F4', 'F4'],
#  'D5 E5': ['C4', 'C4', 'F5'],
#  'G4 G5': ['E4', 'A5', 'A5', 'C5', 'A5', 'A5', 'C5'],
#  'G5 E4': ['F5', 'A5'],
#  'E4 F5': ['A3', 'G4', 'G4', 'G4', 'G4', 'G4'],
#  'F5 A3': ['C4', 'E5', 'C6', 'C6'],
#  'C4 E5': ['E4', 'E4', 'E4'],
#  'D5 D3': ['A3', 'A3'],
#  'D3 A3': ['F5', 'D4', 'D4', 'D6', 'D5', '5+9', 'D4'],
#  'A3 F5': ['D4', 'E5', 'G5'],
#  'F5 D4': ['G5', 'F4', 'F4', 'F5', 'G5', 'E5', 'F4', 'F4', 'F5'],
#  'D4 G5': ['A3', 'F4', 'B-3', 'A3', 'A5', '11+2+4+7', 'F4', 'B-3', 'A3'],
#  'G5 A3': ['A5', 'A5', 'A5', 'A5', 'A5'],
#  'A3 A5': ['G3', 'C4', 'C4', 'G5', 'C4'],
#  'A5 G3': ['B-3'],
#  'G3 B-3': ['D4', 'E5', 'D4'],
#  'D4 B-3': ['G4', 'D4', 'D4', 'D4', 'D4', 'G3', 'D3'],
#  'B-3 G4': ['G3'],
#  'G4 G3': ['A4'],
#  'G3 A4': ['B-3'],
#  'B-3 B-4': ['D4'],
#  'B-4 D4': ['F5'],
#  'D4 F5': ['B-3', 'F4', 'F4', 'E5', 'F4', 'F4', 'C4', 'E5', 'A3'],
#  'F5 B-3': ['0+4'],
#  'B-3 0+4': ['A3'],
#  '0+4 A3': ['A4'],
#  'A4 G5': ['F5', 'C5', 'C5'],
#  'G5 F5': ['E5', 'D2', 'D2', 'D4', 'D2', 'D2'],
#  'F5 E5': ['D5',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C2',
#   'D5',
#   '2+5+9',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C2',
#   'D4',
#   'A3',
#   'A3'],
#  'E5 D5': ['C5', 'G4'],
#  'D5 C5': ['D5', 'A3', 'A3'],
#  'C5 D5': ['D3'],
#  'A3 D4': ['E4', 'E4', '2+4'],
#  'D4 E4': ['F4', 'F4'],
#  'E4 F4': ['E4', 'E4', 'E4', 'E4', 'E4', 'E4'],
#  'F4 E4': ['D4', 'D4', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3'],
#  'E4 D4': ['A4', 'A4', 'D3', 'C4', 'C4'],
#  'D4 A4': ['E4', 'E4'],
#  'A4 E4': ['D3', 'D4'],
#  'E4 D3': ['A3'],
#  'D4 D3': ['E4', 'E4', 'E4', 'E4'],
#  'D3 E4': ['F4', 'D4', 'F4', 'F4', 'D4', 'F4'],
#  'E4 C3': ['F4', 'F4', 'F4', 'C4', 'F4', 'F4', 'F4', 'C4'],
#  'C3 F4': ['G4', 'D3', 'G4', 'G4', 'D3', 'G4'],
#  'F4 G4': ['A4', 'A4', 'A4', 'A4'],
#  'G4 A4': ['F3', 'F3', 'F3', 'F3'],
#  'F3 B-4': ['A4', 'A4', 'A4', 'A4'],
#  'B-4 A4': ['G4', 'G4', 'G4', 'G4'],
#  'G4 C3': ['D3', 'D3', 'D3', 'D3'],
#  'C3 D3': ['E3', 'E3', 'E3', 'E3'],
#  'D3 E3': ['A4', 'A4', 'A4', 'A4'],
#  'E3 A4': ['F3', 'B-2', 'F3', 'B-2'],
#  'F3 G4': ['F4', 'F4'],
#  'G4 F4': ['E4', 'E4', 'E4', 'E4'],
#  'F4 D3': ['E4', 'E4'],
#  'D4 C4': ['A2', 'E4', 'A2'],
#  'C4 A2': ['D4', 'D4'],
#  'A2 D4': ['D3', 'D3'],
#  'A4 B-2': ['G4', 'G4'],
#  'B-2 G4': ['F4', 'F4'],
#  'C3 C4': ['C4', 'C4'],
#  'C4 C4': ['G3', 'G3'],
#  'C4 G3': ['D4', 'D4'],
#  'G3 D4': ['D4', 'D4'],
#  'D4 D4': ['7+11', '7+11'],
#  'D4 7+11': ['D5', '2', 'D5'],
#  '7+11 D5': ['D4', 'D4'],
#  'D5 D4': ['F4', 'F4', 'G5', 'F4', 'F4'],
#  'E5 A4': ['F5', 'D5', 'F5', 'F5', 'D5', 'F5'],
#  'A4 F5': ['E5', 'E5', 'E5', 'E5'],
#  'F5 G4': ['G5', 'G5', 'E5', 'G5', 'G5'],
#  'G5 A5': ['F4', 'F4', 'D5', 'F3', 'F4', 'F4'],
#  'A5 F4': ['A4', 'A4', 'A4', 'D4', 'G5', 'B-5', 'A4', 'A4', 'A4', 'D4'],
#  'A4 B-5': ['C5', 'C5', 'C5', 'C5'],
#  'B-5 C5': ['A5', 'A5', 'A5', 'A5'],
#  'C5 A5': ['G5', 'F4', 'G5', 'B-3', 'G5', 'F4', 'G5', 'B-3'],
#  'A5 G5': ['C4', 'C4', 'D4', 'C4', 'C4'],
#  'G5 C4': ['G4', 'G4', 'E4', 'G4', 'G4'],
#  'G4 C5': ['A5', 'F5', 'A5', 'D4', 'A5', 'F5', 'A5', 'D4'],
#  'G5 C5': ['F5', 'F5', 'F5', 'F5'],
#  'C5 F5': ['E5', 'D4', 'D4', 'E5', 'D4', 'D4'],
#  'A4 D5': ['C5', 'D4', 'E5', 'C5', 'D4'],
#  'C5 A3': ['E4', 'C4', 'E4', 'C4'],
#  'A3 E4': ['A4', 'A4'],
#  'A5 B-3': ['D4', 'B-5', 'D4', 'E6'],
#  'G5 F4': ['F5', 'F5'],
#  'E4 C5': ['G4', 'G4'],
#  'C5 G4': ['C5', 'C5'],
#  'C5 D4': ['D5', 'D5'],
#  'D5 F4': ['D5', 'D5'],
#  'F4 D5': ['A4', 'A4'],
#  'D5 A4': ['E5', 'E5'],
#  'A4 E5': ['D4', 'C4', 'D4', 'C4', 'D3'],
#  'D4 G4': ['G5', 'G5'],
#  'G4 D5': ['B-3', 'B-3'],
#  'F4 C5': ['A3', 'A3'],
#  'E4 10+2+5': ['C4', 'C4'],
#  '10+2+5 C4': ['G5', 'G5'],
#  'C4 G5': ['5+9+0', '5+9+0', 'E4'],
#  'G5 5+9+0': ['F2', 'F2', 'F2', 'F2'],
#  '5+9+0 F2': ['C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6'],
#  'F2 C6': ['F2', 'F2', 'F2', 'F2', 'F2', 'F2', 'F2', 'F2'],
#  'C6 F2': ['0+4+7', '0+4+7', '0+4+7', 'E6', '0+4+7', '0+4+7', '0+4+7', 'E6'],
#  'F2 0+4+7': ['C2', 'C2', 'C2', 'C2', 'C2', 'C2'],
#  '0+4+7 C2': ['C2', 'F5', 'C2', 'C2', 'F5', 'C2'],
#  'C2 C2': ['2+5+9', '2+5+9', '2+5+9', '2+5+9'],
#  'C2 2+5+9': ['D2', 'B-2', 'D2', 'D2', 'B-2', 'D2'],
#  '2+5+9 D2': ['G5', 'G5', 'G5', 'G5'],
#  'D2 G5': ['F5', 'F5', 'F5', 'F5'],
#  'F5 D2': ['D5', 'D5', 'D5', 'D5'],
#  'D2 D5': ['B-2', 'B-2', 'B-2', 'B-2'],
#  'D5 B-2': ['F5', 'F5', 'F5', 'F5'],
#  'B-2 F5': ['F5', 'F5', 'F5', 'F5'],
#  'F5 F5': ['G5', 'G5', 'G5', 'G5'],
#  'F5 G5': ['B-2', 'B-2', 'A5', 'B-2', 'B-2', 'D4'],
#  'G5 B-2': ['5+9+0', '5+9+0', '5+9+0', '5+9+0'],
#  'B-2 5+9+0': ['F2', 'F2', 'F2', 'F2'],
#  'C2 F5': ['E5', 'E5'],
#  'E5 C2': ['2+5+9', '2+5+9'],
#  '2+5+9 B-2': ['B-2', 'B-2', 'B-2', 'B-2'],
#  'B-2 B-2': ['B-2',
#   '10+2+5',
#   'B-2',
#   'B-2',
#   'B-2',
#   'D6',
#   'B-2',
#   '10+2+5',
#   'B-2',
#   'B-2',
#   'B-2',
#   'D6'],
#  'B-2 10+2+5': ['C3', 'C3'],
#  '10+2+5 C3': ['G5', 'G5'],
#  'C3 G5': ['5+9+0', '5+9+0'],
#  'F2 E6': ['A2', 'A2'],
#  'E6 A2': ['C6', 'C6'],
#  'A2 C6': ['A2', 'A2'],
#  'C6 A2': ['2+5+9', '2+5+9'],
#  'A2 2+5+9': ['B-2', 'B-2'],
#  'B-2 D6': ['C6', 'C6'],
#  'D6 C6': ['B-5', 'C4', 'B-5'],
#  'C6 B-5': ['A5', 'A5'],
#  'B-5 A5': ['A3', 'D3', 'A3'],
#  'A5 A3': ['C4', 'C4', 'C4', 'C4'],
#  'C4 A3': ['C4', 'C4', 'C4', 'C4', 'C4', 'C4', 'D3'],
#  'C4 C6': ['E4', 'E4'],
#  'C6 E4': ['C4', 'D6', 'C4'],
#  'C4 A5': ['A3', 'A3', '9+2'],
#  'B-3 F5': ['D4', 'D4', 'A3'],
#  'F5 F4': ['D4', 'D4', 'D4', 'D4'],
#  'D4 A5': ['F4', 'F4', 'F4'],
#  'G5 B-3': ['D4', 'D4'],
#  'A5 C4': ['C5', 'B-5', 'C5'],
#  'C4 C5': ['E4', 'D3', 'E4'],
#  'C5 E4': ['C4', 'C4'],
#  'C4 9+0+4': ['A5', 'A5'],
#  '9+0+4 A5': ['E6', 'E6'],
#  'A5 E6': ['C6', 'C6'],
#  'E6 C6': ['D6', 'D6'],
#  'C6 D6': ['B-3', 'C4', 'B-3'],
#  'D6 B-3': ['D4', 'D4'],
#  'E4 G5': ['G4', 'A3', 'G3'],
#  'G5 G4': ['F5'],
#  'G4 F5': ['E4'],
#  'F5 E4': ['E5', 'G5'],
#  'E4 E5': ['F5'],
#  'E5 F5': ['A3', 'D4', 'E4', 'E5', '2+5+9'],
#  'A3 E5': ['C4', 'F5', 'C4'],
#  'E4 D5': ['C4'],
#  'D5 C4': ['C5'],
#  'C5 D3': ['D5'],
#  'D3 D5': ['A3', 'G5'],
#  'D5 A3': ['E5'],
#  'A5 D5': ['G3'],
#  'G3 C5': ['B-3'],
#  'C5 B-3': ['D4'],
#  'B-4 B-3': ['A4'],
#  'B-3 A4': ['B-4'],
#  'A4 B-4': ['C3'],
#  'B-4 C3': ['C5'],
#  'C3 C5': ['G3'],
#  'C5 G3': ['D5'],
#  'G3 D5': ['E5'],
#  'C4 F5': ['G5'],
#  'A5 F3': ['F2'],
#  'F3 F2': ['5+9'],
#  'F2 5+9': ['9+0'],
#  '5+9 9+0': ['G2'],
#  '9+0 G2': ['1+7'],
#  'G2 1+7': ['A2'],
#  '1+7 A2': ['11+2'],
#  'A2 11+2': ['B2'],
#  '11+2 B2': ['0+4'],
#  'B2 0+4': ['C#3'],
#  '0+4 C#3': ['2+5+9'],
#  'C#3 2+5+9': ['B-3'],
#  '2+5+9 B-3': ['D4'],
#  'F4 G5': ['F5'],
#  'D4 E5': ['G5'],
#  'E5 G5': ['C4'],
#  'C4 B-5': ['C6', 'A5', 'A2'],
#  'B-5 C6': ['E4'],
#  'E4 D6': ['C6'],
#  'C6 C4': ['B-5', 'D6', 'B-5'],
#  'A5 D3': ['G5'],
#  'D3 G5': ['A3'],
#  'G5 D4': ['F5', 'F5'],
#  'D5 G4': ['7+10'],
#  'G4 7+10': ['B-4'],
#  '7+10 B-4': ['D5'],
#  'B-4 D5': ['G5'],
#  'D5 G5': ['7+10', '2+5+9'],
#  'G5 7+10': ['B-5'],
#  '7+10 B-5': ['D6'],
#  'B-5 D6': ['E5'],
#  'D6 E5': ['4+9'],
#  'E5 4+9': ['A5'],
#  '4+9 A5': ['C6'],
#  'A5 C6': ['E6'],
#  'C6 E6': ['A6'],
#  'E6 A6': ['5+7'],
#  'A6 5+7': ['E6'],
#  '5+7 E6': ['A5'],
#  'E6 A5': ['B-3'],
#  'B-3 B-5': ['D4'],
#  'B-5 D4': ['C6', 'C6'],
#  'D4 C6': ['A5', 'D6'],
#  'C6 A5': ['F4'],
#  'F4 B-5': ['D4'],
#  'D6 C4': ['E6'],
#  'C4 E6': ['E4'],
#  'E6 E4': ['E6', 'F6'],
#  'E4 E6': ['G4'],
#  'E6 G4': ['E6'],
#  'G4 E6': ['E4'],
#  'E4 F6': ['E6'],
#  'F6 E6': ['D3'],
#  'E6 D3': ['A3'],
#  'A3 D6': ['D6'],
#  'D6 D6': ['D4'],
#  'D6 D4': ['7+10+2'],
#  'D4 7+10+2': ['D3'],
#  '7+10+2 D3': ['D5'],
#  'G5 2+5+9': ['D3'],
#  '2+5+9 D3': ['A3', 'A3'],
#  'A3 D5': ['D5'],
#  'D5 D5': ['D4'],
#  'G5 11+2+4+7': ['D3'],
#  '11+2+4+7 D3': ['E5'],
#  'D3 E5': ['F5', 'A3', 'A3'],
#  'E5 2+5+9': ['D3'],
#  'A3 5+9': ['D4'],
#  '5+9 D4': ['7+11'],
#  '7+11 2': ['4+7'],
#  '2 4+7': ['2+5'],
#  '4+7 2+5': ['A4'],
#  '2+5 A4': ['D5'],
#  'F5 2+5+9': ['D4'],
#  '2+5+9 D4': ['D3'],
#  'G4 A5': ['E4'],
#  'A5 E4': ['G5'],
#  'G5 G3': ['B-3'],
#  'B-3 G3': ['B-3'],
#  'B-3 D3': ['E5'],
#  'E5 A3': ['F5', 'F5', 'A4', 'E5'],
#  'A3 D3': ['E5', 'A3'],
#  'E5 D3': ['F5'],
#  'D3 F5': ['E5'],
#  'D4 2+4': ['5+7'],
#  '2+4 5+7': ['A5'],
#  '5+7 A5': ['D4'],
#  'A5 D4': ['B-5'],
#  'D4 B-5': ['F4'],
#  'B-5 F4': ['F6'],
#  'F4 F6': ['C4'],
#  'F6 C4': ['G5'],
#  'E4 A5': ['B-3'],
#  'B-3 E6': ['D4'],
#  'E6 D4': ['F5'],
#  'A3 C6': ['C4', 'C4'],
#  'C4 D6': ['G3'],
#  'D6 G3': ['E5'],
#  'G3 E5': ['B-3', 'C4'],
#  'E5 B-3': ['F5'],
#  'B-5 A2': ['D5'],
#  'A2 D5': ['G3'],
#  'A5 9+2': ['2+4'],
#  '9+2 2+4': ['A4']}

# %%
#generate melody based on trigram model and pattern recognition on ngram_dict
generated_melody = generate_trigram("B-3 D4", 100, dictionaries[6])
print(generated_melody)
# Out:
# B-3 D4 F4 C5 A3 E4 A4 D5 D4 F4 E5 C4 E4 C4 9+0+4 A5 E6 C6 D6 B-3 D4 F4 E5 C4 E4 F5 G4 G5 A5 F3 F2 5+9 9+0 G2 1+7 A2 11+2 B2 0+4 C#3 2+5+9 B-3 D4 F4 E5 C4 E4 C5 G4 C5 A5 F4 A4 B-5 C5 A5 B-3 D4 G5 F4 F5 E5 C2 2+5+9 D2 G5 F5 D4 F5 F4 D4 B-3 D4 B-4 F4 F5 E5 C4 E4 C4 9+0+4 A5 E6 C6 D6 C4 E6 E4 F6 E6 D3 A3 D4 E4 F4 E4 C3 F4 G4 A4 F3 G4

# %%
#create suitable format for playing midi file concatenating the string with the notation and tempo
generated_melody = "tinynotation: 4/4" + generated_melody

# %%
littleMelody = converter.parse(generated_melody)
littleMelody.show('midi')
# Out:
#                 <div id="midiPlayerDiv1387429"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv1387429");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %%
#saving
littleMelody.write("midi", "testaudio.mkv")
# Out:
# 'testaudio.mkv'
